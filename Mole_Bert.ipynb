# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/junxia97/Mole-BERT.git
# Out:
# Cloning into 'Mole-BERT'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 49 (delta 3), reused 3 (delta 3), pack-reused 42 (from 1)
# Receiving objects: 100% (49/49), 6.69 MiB | 29.26 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# %cd Mole-BERT
# Out:
# /content/Mole-BERT

# %%
# !ln -s "/content/drive/MyDrive/Luan van thac sy/Flame/Pretrained/Mole-BERT/Models" "/content/Mole-BERT"
# !ln -s "/content/drive/MyDrive/Luan van thac sy/Flame/Pretrained/Mole-BERT/dataset" "/content/Mole-BERT"

# %% [markdown]
# # Task
# Download the "http://snap.stanford.edu/gnn-pretrain/data/chem_dataset.zip" file, unzip its contents, create a directory named `dataset/`, and then move the extracted files into this `dataset/` directory.

# %% [markdown]
# ## Download Dataset
#
# ### Subtask:
# Download the chem_dataset.zip file from http://snap.stanford.edu/gnn-pretrain/data/chem_dataset.zip.

# %% [markdown]
# **Reasoning**:
# To download the specified zip file, I will use the `wget` command as instructed.

# %%
get_ipython().system('wget http://snap.stanford.edu/gnn-pretrain/data/chem_dataset.zip')
# Out:
# --2025-12-08 08:12:25--  http://snap.stanford.edu/gnn-pretrain/data/chem_dataset.zip
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2513247210 (2.3G) [application/zip]
# Saving to: ‘chem_dataset.zip’
#
# chem_dataset.zip    100%[===================>]   2.34G  38.6MB/s    in 63s
#
# 2025-12-08 08:13:28 (38.3 MB/s) - ‘chem_dataset.zip’ saved [2513247210/2513247210]

# %% [markdown]
# **Reasoning**:
# The next logical step is to unzip the downloaded `chem_dataset.zip` file. I will use the `unzip` command for this purpose.

# %%
get_ipython().system('unzip chem_dataset.zip')
# Out:
# Archive:  chem_dataset.zip
#    creating: dataset/zinc_standard_agent/
#    creating: dataset/zinc_standard_agent/processed/
#   inflating: dataset/zinc_standard_agent/processed/smiles.csv
#   inflating: dataset/zinc_standard_agent/processed/geometric_data_processed.pt
#    creating: dataset/zinc_standard_agent/raw/
#   inflating: dataset/zinc_standard_agent/raw/zinc_combined_apr_8_2019.csv.gz
#    creating: dataset/hiv/
#   inflating: dataset/hiv/HIV_README
#    creating: dataset/hiv/raw/
#   inflating: dataset/hiv/raw/HIV.csv
#    creating: dataset/hiv/processed/
#   inflating: dataset/hiv/processed/smiles.csv
#   inflating: dataset/hiv/processed/geometric_data_processed.pt
#    creating: dataset/bace/
#    creating: dataset/bace/processed/
#   inflating: dataset/bace/processed/geometric_data_processed.pt
#   inflating: dataset/bace/processed/smiles.csv
#   inflating: dataset/bace/BACE_README
#    creating: dataset/bace/raw/
#   inflating: dataset/bace/raw/bace.csv
# ...

# %%
# !pip install rdkit
# !pip install torch-geometric
# !pip install torch-scatter
# !pip install torch-sparse
# !pip install torch-spline-conv
# !pip install torch_cluster
# !pip install tensorboardx
# !pip install tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 63.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.2-cp312-cp312-linux_x86_64.whl size=3857020 sha256=eaff100d153e1c02adb208e06e00e71c830a58913c4a656a2525e21837be9212
#   Stored in directory: /root/.cache/pip/wheels/84/20/50/44800723f57cd798630e77b3ec83bc80bd26a1e3dc3a672ef5
# Successfully built torch-scatter
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.0/210.0 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.18-cp312-cp312-linux_x86_64.whl size=3039801 sha256=12b34fe8e16e7c43cabd3b5c9398ec2860ab1c07448d5fe287e836203f3d1cb5
# ...

# %% [markdown]
# # Pretrain model

# %%
# !python vqvae.py --device 0 --output_model_file Models/
# Out:
# Streaming output truncated to the last 5000 lines.
# 1822410
# 1822411
# 1822412
# 1822413
# 1822414
# 1822415
# 1822416
# 1822417
# 1822418
# 1822419
# 1822420
# 1822421
# 1822422
# 1822423
# 1822424
# 1822425
# 1822426
# 1822427
# 1822428
# 1822429
# 1822430
# 1822431
# 1822432
# 1822433
# 1822434
# 1822435
# 1822436
# 1822437
# 1822438
# 1822439
# 1822440
# 1822441
# 1822442
# 1822443
# 1822444
# 1822445
# 1822446
# 1822447
# 1822448
# 1822449
# 1822450
# 1822451
# 1822452
# 1822453
# 1822454
# 1822455
# 1822456
# 1822457
# 1822458
# 1822459
# 1822460
# 1822461
# 1822462
# 1822463
# 1822464
# 1822465
# 1822466
# 1822467
# 1822468
# 1822469
# 1822470
# 1822471
# 1822472
# 1822473
# 1822474
# 1822475
# 1822476
# 1822477
# 1822478
# 1822479
# 1822480
# 1822481
# 1822482
# 1822483
# 1822484
# 1822485
# 1822486
# 1822487
# 1822488
# 1822489
# 1822490
# 1822491
# 1822492
# 1822493
# 1822494
# 1822495
# 1822496
# 1822497
# 1822498
# 1822499
# 1822500
# 1822501
# 1822502
# 1822503
# ...

# %%
# !python pretrain.py --output_model_file Models/
# Out:
# Traceback (most recent call last):
#   File "/content/Mole-BERT/pretrain.py", line 25, in <module>
#     triplet_loss = nn.TripletMarginLoss(margin=0.0, p=2)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py", line 1775, in __init__
#     raise ValueError(
# ValueError: TripletMarginLoss: expected margin to be greater than 0, got 0.0 instead
